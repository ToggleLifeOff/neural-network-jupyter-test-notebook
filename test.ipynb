# %%
import torch
from torch import nn
import random

# %%
def mystery(a,b):
  return torch.tensor(a+3*b)

# %%
model = nn.Sequential(nn.Linear(2,1))
model
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=1, bias=True)
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
for i in range(1000):
  a = random.random()
  b = random.random()
  desiredOutput = mystery (a,b)

  output = model(torch.tensor([a,b]))
  loss = criterion(output.squeeze(), desiredOutput)

  if (i % 100)==0:
    print (f"Loss: {loss.item()} ")
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Loss: 10.243589401245117
# Loss: 0.3870306611061096
# Loss: 3.1018054485321045
# Loss: 3.2791574001312256
# Loss: 0.769962728023529
# Loss: 2.9289052486419678
# Loss: 0.4920569956302643
# Loss: 0.9742635488510132
# Loss: 0.45790594816207886
# Loss: 2.7883623261004686e-05

# %%
a = 1.0
b = -1.0
output = model(torch.tensor([a,b]))
print (output.item())
# Out:
# -0.021062374114990234

# %%
mystery(a,b)
# Out:
# tensor(-2.)
